# %% [markdown]
# # Data Import

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
athlete_data = pd.read_csv('athlete_events.csv', index_col = 0)
regional_data = pd.read_csv('noc_regions.csv')
track_data = pd.read_csv('results.csv',  names = ('Gender', 'Event', 'Location', 'Year', 'Medal', 'Name', 'Nationality', 'Result'))

# %%
track_data.shape
# Out:
# (2395, 8)

# %%
athlete_data.shape
# Out:
# (271116, 14)

# %%
athlete_data = athlete_data[athlete_data['Sport'] == 'Athletics']

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# -  Replace Gold, Silver, Bronze, Other with 1, 2, 3, 4
# -  Replace Male, Female with 1, 2
# -  Replace Summer, Winter with 1, 2
# -  Change Age to int, missing values = -1

# %%
athlete_data['Medal'].replace('Gold', 1, inplace = True)
athlete_data['Medal'].replace('Silver', 2, inplace = True)
athlete_data['Medal'].replace('Bronze', 3, inplace = True)
athlete_data['Medal'].replace(np.nan, 4, inplace = True)

athlete_data['Sex'].replace('M', 1, inplace = True)
athlete_data['Sex'].replace('F', 2, inplace = True)

athlete_data['Season'].replace('Summer', 1, inplace = True)
athlete_data['Season'].replace('Winter', 2, inplace = True)

athlete_data['Age'].replace(np.nan, -1, inplace = True)
athlete_data['Age'] = athlete_data['Age'].astype(int)

athlete_data.sort_values('Year', ascending = True, inplace = True)

athlete_data
# Out:
#                                                      Name  Sex  Age  Height  \
# ID
# 49185                                       Fritz Hofmann    1   24   167.0
# 38860                                Robert "Bob" Garrett    1   20   188.0
# 38860                                Robert "Bob" Garrett    1   20   188.0
# 38860                                Robert "Bob" Garrett    1   20   188.0
# 54456                              Alexander Viggo Jensen    1   21     NaN
# 54456                              Alexander Viggo Jensen    1   21     NaN
# 107090                                Eugen Stahl Schmidt    1   34     NaN
# 26280                          Georges Daviel de la Nzire    1   17     NaN
# 68911                            Albin Georges Lermusiaux    1   21     NaN
# 68911                            Albin Georges Lermusiaux    1   21     NaN
# 38860                                Robert "Bob" Garrett    1   20   188.0
# 68911                            Albin Georges Lermusiaux    1   21     NaN
# 111580                          Athanasios Skaltsogiannis    1   -1     NaN
# 39654                                 Evangelos Gerakakis    1   -1     NaN
# 53542                          Herbert Brotherson Jamison    1   20   173.0
# 29084                                 Kurt Wilhelm Doerry    1   21   179.0
# 29084                                 Kurt Wilhelm Doerry    1   21   179.0
# 29084                                 Kurt Wilhelm Doerry    1   21   179.0
# 91250                        Georgios Saranti Papasideris    1   -1     NaN
# 91250                        Georgios Saranti Papasideris    1   -1     NaN
# 91251                              Eleftherios Papasymeon    1   -1     NaN
# 111580                          Athanasios Skaltsogiannis    1   -1     NaN
# 38123                                          Carl Galle    1   23   154.0
# 16616                           Thomas Edmund "Tom" Burke    1   21   183.0
# 16616                           Thomas Edmund "Tom" Burke    1   21   183.0
# 57441                           Konstantinos Karakatsanis    1   -1     NaN
# 107613                                     Carl Schuhmann    1   26   159.0
# 71674                             Spyridon "Spyros" Louis    1   23     NaN
# 126142                                    Sotirios Versis    1   -1     NaN
# 16616           Athina  Athletics
# 16616           Athina  Athletics
# 57441           Athina  Athletics
# 107613          Athina  Athletics
# 71674           Athina  Athletics
# 126142          Athina  Athletics
# 4113            Athina  Athletics
# ...                ...        ...
# 78347   Rio de Janeiro  Athletics
# 30379   Rio de Janeiro  Athletics
# 78398   Rio de Janeiro  Athletics
# 19896   Rio de Janeiro  Athletics
# 7348    Rio de Janeiro  Athletics
# 30644   Rio de Janeiro  Athletics
# 97643   Rio de Janeiro  Athletics
# 97647   Rio de Janeiro  Athletics
# 97683   Rio de Janeiro  Athletics
# 19795   Rio de Janeiro  Athletics
# 49149   Rio de Janeiro  Athletics
# 7246    Rio de Janeiro  Athletics
# 7226    Rio de Janeiro  Athletics
# 78565   Rio de Janeiro  Athletics
# 78557   Rio de Janeiro  Athletics
# 49950   Rio de Janeiro  Athletics
# 78557   Rio de Janeiro  Athletics
# 78514   Rio de Janeiro  Athletics
# 78512   Rio de Janeiro  Athletics
# 123746  Rio de Janeiro  Athletics
# 49153   Rio de Janeiro  Athletics
# 123780  Rio de Janeiro  Athletics
# 7187    Rio de Janeiro  Athletics
# 49322   Rio de Janeiro  Athletics
# 49398   Rio de Janeiro  Athletics
# 78451   Rio de Janeiro  Athletics
# 78432   Rio de Janeiro  Athletics
# 97767   Rio de Janeiro  Athletics
# 78531   Rio de Janeiro  Athletics
# 119903  Rio de Janeiro  Athletics
#
#                                               Event  Medal
# ID
# 49185                    Athletics Men's 400 metres    4.0
# 38860                      Athletics Men's Shot Put    1.0
# 38860                     Athletics Men's Long Jump    2.0
# 38860                     Athletics Men's High Jump    2.0
# 54456                  Athletics Men's Discus Throw    4.0
# 54456                      Athletics Men's Shot Put    4.0
# 107090                   Athletics Men's 100 metres    4.0
# 26280                    Athletics Men's 800 metres    4.0
# 68911                      Athletics Men's Marathon    4.0
# 68911                  Athletics Men's 1,500 metres    3.0
# 38860                  Athletics Men's Discus Throw    1.0
# 68911                    Athletics Men's 800 metres    4.0
# 111580           Athletics Men's 110 metres Hurdles    4.0
# 39654                      Athletics Men's Marathon    4.0
# 53542                    Athletics Men's 400 metres    2.0
# 29084            Athletics Men's 110 metres Hurdles    4.0
# 29084                    Athletics Men's 400 metres    4.0
# 29084                    Athletics Men's 100 metres    4.0
# 91250                      Athletics Men's Shot Put    3.0
# 91250                  Athletics Men's Discus Throw    4.0
# 91251                      Athletics Men's Marathon    4.0
# 111580                    Athletics Men's Long Jump    4.0
# 38123                  Athletics Men's 1,500 metres    4.0
# 16616                    Athletics Men's 100 metres    1.0
# 16616                    Athletics Men's 400 metres    1.0
# 57441                  Athletics Men's 1,500 metres    4.0
# 107613                    Athletics Men's Long Jump    4.0
# 71674                      Athletics Men's Marathon    1.0
# 126142                 Athletics Men's Discus Throw    3.0
# 4113             Athletics Men's 110 metres Hurdles    4.0
# ...                                             ...    ...
# 78347     Athletics Men's 3,000 metres Steeplechase    3.0
# 30379                     Athletics Men's Decathlon    4.0
# 78398                    Athletics Women's Marathon    4.0
# 19896          Athletics Men's 4 x 400 metres Relay    4.0
# 7348                     Athletics Men's Pole Vault    4.0
# 30644            Athletics Men's 20 kilometres Walk    4.0
# 97643                  Athletics Women's 400 metres    4.0
# 97647          Athletics Men's 4 x 400 metres Relay    4.0
# 97683   Athletics Women's 3,000 metres Steeplechase    4.0
# 19795                 Athletics Men's 10,000 metres    4.0
# 49149                   Athletics Men's Triple Jump    4.0
# 7246                   Athletics Men's 5,000 metres    4.0
# 7226           Athletics Men's 4 x 400 metres Relay    4.0
# 78565                    Athletics Men's Pole Vault    4.0
# 78557          Athletics Men's 4 x 100 metres Relay    4.0
# 49950                  Athletics Women's 100 metres    4.0
# 78557                    Athletics Men's 200 metres    4.0
# 78514        Athletics Women's 4 x 400 metres Relay    4.0
# 78512                  Athletics Women's Heptathlon    4.0
# 123746                Athletics Men's Javelin Throw    4.0
# 49153        Athletics Women's 4 x 400 metres Relay    4.0
# 123780         Athletics Women's 20 kilometres Walk    4.0
# 7187                   Athletics Women's 800 metres    4.0
# 49322          Athletics Women's 100 metres Hurdles    4.0
# 49398          Athletics Women's 20 kilometres Walk    4.0
# 78451                   Athletics Women's Long Jump    4.0
# 78432                  Athletics Men's Hammer Throw    4.0
# 97767          Athletics Women's 20 kilometres Walk    4.0
# 78531          Athletics Women's 20 kilometres Walk    4.0
# 119903       Athletics Women's 4 x 100 metres Relay    2.0
#
# [38624 rows x 14 columns]

# %%
track_data.head()
# Out:
#    Gender       Event  Location  Year  Medal                   Name  \
# 0  Gender       Event  Location  Year  Medal                   Name
# 1       M  10000M Men       Rio  2016      G          Mohamed FARAH
# 2       M  10000M Men       Rio  2016      S  Paul Kipngetich TANUI
# 3       M  10000M Men       Rio  2016      B           Tamirat TOLA
# 4       M  10000M Men   Beijing  2008      G        Kenenisa BEKELE
#
#    Nationality    Result
# 0  Nationality    Result
# 1          USA  25:05.17
# 2          KEN  27:05.64
# 3          ETH  27:06.26
# 4          ETH  27:01.17

# %%
track_data['Medal'].replace('G', 1, inplace = True)
track_data['Medal'].replace('S', 2, inplace = True)
track_data['Medal'].replace('B', 3, inplace = True)
track_data['Medal'].replace(np.nan, 4, inplace = True)

track_data['Gender'].replace('M', 1, inplace = True)
track_data['Gender'].replace('F', 2, inplace = True)

track_data.sort_values('Year', ascending = True, inplace = True)
track_data
# Out:
#       Gender               Event  Location  Year  Medal  \
# 665        1            400M Men    Athens  1896      3
# 1373       1       Long Jump Men    Athens  1896      1
# 1457       1        Marathon Men    Athens  1896      1
# 1145       1    Discus Throw Men    Athens  1896      2
# 1146       1    Discus Throw Men    Athens  1896      3
# 151        1            100M Men    Athens  1896      3
# 1458       1        Marathon Men    Athens  1896      2
# 150        1            100M Men    Athens  1896      3
# 149        1            100M Men    Athens  1896      2
# 1459       1        Marathon Men    Athens  1896      3
# 148        1            100M Men    Athens  1896      1
# 231            Grantley GOULDING         GBR      17.7
# 1518      Ioannis THEODOROPOULOS         GRE       2.6
# 1517          Evangelos DAMASKOS         GRE       2.6
# 1516                Albert TYLER         USA       3.2
# 1515         William Welles HOYT         USA       3.3
# 310                  Edwin FLACK         AUS    4:33.2
# 311                 Arthur BLAKE         USA    4:34.0
# 1260                Ellery CLARK         USA      1.81
# 312             Albin LERMUSIAUX         FRA    4:36.0
# 1578        Georgios PAPASIDERIS         GRE     10.36
# 1374              Robert GARRETT         USA      6.18
# 1144              Robert GARRETT         USA     29.15
# 664              Herbert JAMISON         USA      55.2
# 1261              Robert GARRETT         USA      1.65
# 1632            Ioannis PERSAKIS         GRE     12.52
# 1375              James CONNOLLY         USA      6.11
# ...                          ...         ...       ...
# 513              Yasmani COPELLO         TUR     47.92
# 512             Boniface MUCHERU         KEN     47.78
# 511               Kerron CLEMENT         USA     47.73
# 1203           Bohdan BONDARENKO         UKR      2.33
# 1201                Derek DROUIN         CAN      2.38
# 441           Mahiedine MEKHISSI         FRA   8:11.52
# 440                   Evan JAGER         USA   8:04.28
# 439            Conseslus KIPRUTO         KEN   8:03.28
# 313                   Usain BOLT         JAM     19.78
# 1313              Jeff HENDERSON         USA      8.38
# 586            Wayde VAN NIEKERK         RSA     43.03
# 1376       Eliud Kipchoge ROTICH         KEN  02:08:44
# 1377               Feyisa LILESA         ETH   2:09:54
# 1378                  Galen RUPP         USA   2:10:05
# 587                 Kirani JAMES         GRN     43.76
# 588              Lashawn MERRITT         USA     43.85
# 1012                 Kevin MAYER         FRA    8834.0
# 1011                Ashton EATON         USA    8893.0
# 1460        Thiago Braz DA SILVA         BRA      6.03
# 1461           Renaud LAVILLENIE         FRA      5.98
# 154               Dimitri BASCOU         FRA     13.24
# 932               Clayton MURPHY         USA   1:42.93
# 232           Matthew CENTROWITZ         USA   3:50.00
# 1314               Luvo MANYONGA         RSA      8.37
# 1315             Greg RUTHERFORD         GBR      8.29
# 1089             Daniel JASINSKI         GER     67.05
# 1088           Piotr MALACHOWSKI         POL     67.55
# 1087           Christoph HARTING         GER     68.37
# 234              Nicholas WILLIS         NZL   3:50.24
# 233            Taoufik MAKHLOUFI         ALG   3:50.11
#
# [1632 rows x 8 columns]

# %% [markdown]
# # Data Subsets

# %% [markdown]
# -  Medal wins, No Medals Won

# %%
# Read athlete_data[athlete_data['Medal'] == 1] as "athlete_data where athlete_data's medal column equals 1"
medal_wins = athlete_data[athlete_data['Medal'] != 4]
non_medal_wins = athlete_data[athlete_data['Medal'] == 4]

summer_sports = athlete_data[athlete_data['Season'] == 1]

# %%
medal_wins['Age'].hist(bins = 50)

# %%
medal_wins['Team'].value_counts()
# Out:
# United States          1071
# Great Britain           334
# Soviet Union            242
# Jamaica                 156
# Germany                 154
# East Germany            140
# Finland                 138
# Sweden                  128
# France                  110
# Russia                  103
# Kenya                    99
# Canada                   98
# Australia                88
# Poland                   72
# Italy                    72
# West Germany             71
# Cuba                     58
# Ethiopia                 53
# Hungary                  52
# Nigeria                  41
# Greece                   37
# Bahamas                  36
# Romania                  35
# South Africa             31
# Japan                    31
# Unified Team             29
# Trinidad and Tobago      28
# China                    27
# Brazil                   26
# Czechoslovakia           24
#                        ...
# South Korea               2
# India                     2
# Yugoslavia                2
# Tanzania                  2
# Luxembourg                2
# Iceland                   2
# Philippines               2
# Ecuador                   2
# Cameroon                  2
# Sri Lanka                 2
# Chinese Taipei            2
# Serbia                    1
# Slovakia                  1
# Haiti                     1
# Tajikistan                1
# Australasia               1
# Guatemala                 1
# Senegal                   1
# Puerto Rico               1
# Syria                     1
# Sudan                     1
# Cote d'Ivoire             1
# Barbados                  1
# Saudi Arabia              1
# Zambia                    1
# Eritrea                   1
# Iran                      1
# Botswana                  1
# Bohemia                   1
# Djibouti                  1
# Name: Team, Length: 103, dtype: int64

# %% [markdown]
# ## High-Level Questions

# %% [markdown]
# -  Evalute the performance of different nations based on political climate.
# - Evaluate the performance of different nations based on respective GDP.
# -  Examine the impact of assistive technology (from steroids to track gear) on human performance at the Olympic Games.
# -  Explore the impact of notable controversies on the performance of specific athletes and nations.
#   -   https://en.wikipedia.org/wiki/List_of_Olympic_Games_scandals_and_controversies

# %% [markdown]
# ## Exploratory Questions

# %% [markdown]
# Q1: What is the variation in age of gold medal recipients?
#
# -  Demonstrates variation in physical demands of a given sport
# -  Finds outliers
# -  Could be further broken down in a variety of contexts: country, culture, sport

# %%
gold = athlete_data[(athlete_data.Medal == 1)]
gold.head()
# Out:
#                             Name  Sex  Age  Height  Weight           Team  \
# ID
# 38860       Robert "Bob" Garrett    1   20   188.0    81.0  United States
# 38860       Robert "Bob" Garrett    1   20   188.0    81.0  United States
# 16616  Thomas Edmund "Tom" Burke    1   21   183.0    66.0  United States
# 16616  Thomas Edmund "Tom" Burke    1   21   183.0    66.0  United States
# 71674    Spyridon "Spyros" Louis    1   23     NaN     NaN         Greece
#
#        NOC        Games  Year  Season    City      Sport  \
# ID
# 38860  USA  1896 Summer  1896       1  Athina  Athletics
# 38860  USA  1896 Summer  1896       1  Athina  Athletics
# 16616  USA  1896 Summer  1896       1  Athina  Athletics
# 16616  USA  1896 Summer  1896       1  Athina  Athletics
# 71674  GRE  1896 Summer  1896       1  Athina  Athletics
#
#                               Event  Medal
# ID
# 38860      Athletics Men's Shot Put    1.0
# 38860  Athletics Men's Discus Throw    1.0
# 16616    Athletics Men's 100 metres    1.0
# 16616    Athletics Men's 400 metres    1.0
# 71674      Athletics Men's Marathon    1.0

# %%
#age missing values = -1, take those out
gold = gold.loc[gold['Age'] >= 0]

# %%
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(gold['Age'])
plt.title('Variation in Age - Gold Medal Recipiants')
# Out:
# Text(0.5, 1.0, 'Variation in Age - Gold Medal Recipiants')

# %% [markdown]
# Q2: What does the distribution over time of women medalists look like?
#
# -  Shows high-level cultural changes
# -  Relates to a question with a focus on culture, gender, or identity in globally broadcasted sports
# -  Shows an interesting (and peculiar) exchange from 1992-2016

# %%
women = athlete_data[(athlete_data.Sex == 2)]

# %%
sns.set()
plt.figure(figsize=(20,10))
sns.countplot(women['Year'])
plt.title('All-Women Medal Recipients Over the Years')
# Out:
# Text(0.5, 1.0, 'All-Women Medal Recipients Over the Years')

# %% [markdown]
# ## Data Summary

# %% [markdown]
# Events of interest for our project, within the Athletics department:
#
# - 1500m
# - high jump
# - javelon
# - shot put
# - 4 x 100m relay
# - 100m

# %% [markdown]
# Athletes measured by biometrics and winning times, data stored between athlete_data and track_data. Regional_data may be pulled at our discresion when interested in the impact of specific area on performance. We will classify performance and biometrics within our events of interest by gender to standardize our analysis.

# %% [markdown]
# Q3: Where do the fastest (M) and fastest (W) Athletics athletes come from?

# %%
track_data[track_data['Gender'] == 2]

# %%
track_data_womens = track_data[track_data['Gender'] == 2]
track_data_womens
# Out:
# Empty DataFrame
# Columns: [Gender, Event, Location, Year, Medal, Name, Nationality, Result]
# Index: []

# %%
track_data['Gender'].value_counts()
# Out:
# Series([], Name: Gender, dtype: int64)

# %%
track_data = track_data[track_data['Medal'] == 1]
track_data
# Out:
# Empty DataFrame
# Columns: [Gender, Event, Location, Year, Medal, Name, Nationality, Result]
# Index: []

# %%
# Out:
# Empty DataFrame
# Columns: [Gender, Event, Location, Year, Medal, Name, Nationality, Result]
# Index: []

# %%
track_data['Location'].value_counts()
# Out:
# Series([], Name: Location, dtype: int64)

# %% [markdown]
# The fastest women Athletics athletes have been from London, Beijing, and Rio.

# %%
track_data = track_data[track_data['Gender']==1]

# %%
track_data
# Out:
# Empty DataFrame
# Columns: [Gender, Event, Location, Year, Medal, Name, Nationality, Result]
# Index: []

# %% [markdown]
# # Investigation: Impact of global events on Olympic performance, by country.
#
# Events of interest:
#     - WWI
#     - Great Depression
#     - Cold War data on countries that were figthing in Proxy Wars (neither US/Russia fought, but sent resources) and highly involved in Olympic competition.
#     - Athletic technological advancements?
#     - Controversies?
#         - 1936 Summer Olympics held in Berlin following WW1. How did the Allies/Axis perform? Tense geopolitical environment.

# %%
# Track/Athlete data starts at 1896.

# %% [markdown]
# Investigation 1: 1936 Summer Olympics
#
# This event makes for an intense geopolitical environment for several reasons. WWI ended in 1918, and WWII began in 1939. Economic, social, and political after-effects from the first global war were still largely relevant as countries struggled with poplation disparities, struggling economy, and displaced trade.
#
# Considering that these Olympics were held in Berlin, Germany directly following Hitler's rise to power in 1933, it is well-documented that the Olympic execution plans became entangled with Nazi politics and intense German nationalism.
#
# This entanglement resulted in waves of protest as many countries boycotted the IOC's decision to hold the Olympics in Berlin. Regardless, the events went on as planned. Here's how this affected performance.

# %%
track_data = track_data[track_data['Year']==1936]

# %%
track_data
# Out:
# Empty DataFrame
# Columns: [Gender, Event, Location, Year, Medal, Name, Nationality, Result]
# Index: []
